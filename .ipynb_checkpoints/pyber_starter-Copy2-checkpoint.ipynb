# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load
city = pd.read_csv("data/city_data.csv")
ride = pd.read_csv("data/ride_data.csv")

# Dropping duplicated cities by keeping the first duplicates in the dataset
city = city_df.drop_duplicates('city', keep = 'first')

# Merging the two data series on city
merged = city_df.merge(ride_df, on = 'city')

# %%
merged.head()
# Out:
#           city  driver_count   type             date   fare       ride_id
# 0  Richardfort            38  Urban   2/24/2018 8:40  13.93  5.628550e+12
# 1  Richardfort            38  Urban  2/13/2018 12:46  14.00  9.100500e+11
# 2  Richardfort            38  Urban  2/16/2018 13:52  17.92  8.206390e+11
# 3  Richardfort            38  Urban   2/1/2018 20:18  10.26  9.554940e+12
# 4  Richardfort            38  Urban   4/17/2018 2:26  23.00  7.200210e+11

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
# Using groupby function to group the data by cities
city_grpby = merged_df.groupby('city')

# Total fares by cities
Average_Fares = city_grpby.mean()['fare']

# Total rides by cities
Rides = city_grpby['ride_id'].count()

# Total number of drivers
Total_Number_of_Drivers = city_grpby.mean()['driver_count']

# Types of cities
Type_of_City = city_df.set_index('city')['type']

# Creating a dataframe including ride, fare, driver, and city types data
CityValues = pd.DataFrame({
    "Total Number of Rides": Rides,
    "Average Fares": Average_Fares,
    "Total Number of Drivers": Total_Number_of_Drivers,
    "City Types": Type_of_City
})

CityValues.sort_values("Total Number of Drivers", ascending = False)

#separated dfs for city categories
rural = city_info[city_info["Type of City"] == "Rural"]
suburban = city_info[city_info["Type of City"] == "Suburban"]
urban = city_info[city_info["Type of City"] == 'Urban']

# three scatter plots for each city type
plt.scatter(rural["Number of Rides"], rural["Average Fare"], s = rural["Number of Drivers"]*10, color = city_color["Rural"], edgecolor = "black", label = "Rural", alpha = 0.75)
plt.scatter(suburban["Number of Rides"], suburban["Average Fare"], s = suburban["Number of Drivers"]*10, color = city_color["Suburban"], edgecolor = "black", label = "Suburban", alpha = 0.75)
plt.scatter(urban["Number of Rides"], urban["Average Fare"], s = urban["Number of Drivers"]*10, color = city_color["Urban"], edgecolor = "black", label = "Urban", alpha = 0.75)

# Axis names
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Numbers of Rides (Per City))")
plt.ylabel("Average Fare($)")
plt.legend(loc="upper right")
# Using groupby function to group the data by cities
city_grpby = merged_df.groupby('city')

# Total fares by cities
Average_Fares = city_grpby.mean()['fare']

# Total rides by cities
Rides = city_grpby['ride_id'].count()

# Total number of drivers
Total_Number_of_Drivers = city_grpby.mean()['driver_count']

# Types of cities
Type_of_City = city_df.set_index('city')['type']

# Creating a dataframe including ride, fare, driver, and city types data
CityValues = pd.DataFrame({
    "Total Number of Rides": Rides,
    "Average Fares": Average_Fares,
    "Total Number of Drivers": Total_Number_of_Drivers,
    "City Types": Type_of_City})


CityValues.sort_values("Total Number of Drivers", ascending = False)

#separated dfs for city categories
rural = city_info[city_info["Type of City"] == "Rural"]
suburban = city_info[city_info["Type of City"] == "Suburban"]
urban = city_info[city_info["Type of City"] == 'Urban']

# three scatter plots for each city type
plt.scatter(rural["Number of Rides"], rural["Average Fare"], s = rural["Number of Drivers"]*10, color = city_color["Rural"], edgecolor = "black", label = "Rural", alpha = 0.75)
plt.scatter(suburban["Number of Rides"], suburban["Average Fare"], s = suburban["Number of Drivers"]*10, color = city_color["Suburban"], edgecolor = "black", label = "Suburban", alpha = 0.75)
plt.scatter(urban["Number of Rides"], urban["Average Fare"], s = urban["Number of Drivers"]*10, color = city_color["Urban"], edgecolor = "black", label = "Urban", alpha = 0.75)

#print scatter plot
plt.title('Note : Size of Bubble Corresponds to Number of Drivers per City')
plt.xlabel('Number of Rides per City')
plt.ylabel('Average Fare per City')

lgnd = plt.legend(frameon = True, edgecolor = 'black')
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]

plt.show()

# %%
# Show plot
#plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
grouped = merged.groupby(["type"])

# %%
Total_Number_of_Rides = group["fare"].count()
Fares = group["fare"].sum()
Average_Fares = Fares/Total_Number_of_Rides
Ty = group["type"].unique()

# %%
DatFrame = pd.DataFrame({"Total Number of Rides": Total_Number_of_Rides,
                        "Average Fares": Average_Fares,
                        "City Type": Ty.str.get(0)})

DatFrame.head()
# Out:
#                             Total Number of Rides  Average Fares City Type
# city          driver_count
# Amandaburgh   12                               18      24.641667     Urban
# Barajasview   26                               22      25.332273     Urban
# Barronchester 11                               16      36.422500  Suburban
# Bethanyland   22                               18      32.956111  Suburban
# Bradshawfurt  7                                10      40.064000     Rural

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
